# %%
#import usfull libraire
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data
Dataset_1=pd.read_csv('C:\\Users\\pc\\Desktop\\project2\\dataset_1.csv')
Dataset_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
Dataset_2=pd.read_csv('C:\\Users\\pc\\Desktop\\project2\\dataset_2.csv')
Dataset_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
# number of rows and colomn
Dataset_1.shape,Dataset_2.shape
# Out:
# ((610, 10), (610, 8))

# %%
# merge the data set 1 and 2
commbine_data=pd.merge(Dataset_1,Dataset_2, on='instant')
commbine_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
# shape of grouped data
commbine_data.shape
# Out:
# (610, 17)

# %%
# drop unusefull data 
commbine_data.drop(['Unnamed: 0','atemp'], axis=1)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
# finding unique values 
commbine_data['temp'].unique()
# Out:
# array([0.24, 0.22, 0.2 , 0.32, 0.38, 0.36, 0.42, 0.46, 0.44, 0.4 , 0.34,
#        0.3 , 0.26, 0.16, 0.14, 0.18, 0.12, 0.28, 0.1 , 0.08, 0.06, 0.04,
#        0.02])

# %%
commbine_data['hum'].unique
# Out:
# <bound method Series.unique of 0      0.81
# 1      0.80
# 2      0.80
# 3      0.75
# 4      0.75
#        ...
# 605    0.93
# 606    0.93
# 607    0.93
# 608    0.80
# 609    0.86
# Name: hum, Length: 610, dtype: float64>

# %%
# laod data set3
Dataset_3=pd.read_csv('C:\\Users\\pc\\Desktop\\project2\\dataset_3.csv')
Dataset_3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
#concatinate datas 
final_data= pd.concat([commbine_data,Dataset_3])
final_data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
final_data_1=final_data.drop(['Unnamed: 0','atemp'],axis=1)
final_data_1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
#data Summmry 
final_data_1.describe()
# Out:
#            instant  season      yr         mnth           hr      weekday  \
# count  1000.000000  1000.0  1000.0  1000.000000  1000.000000  1000.000000
# mean    500.500000     1.0     0.0     1.312000    11.753000     2.982000
# std     288.819436     0.0     0.0     0.463542     6.899101     2.091423
# min       1.000000     1.0     0.0     1.000000     0.000000     0.000000
# 25%     250.750000     1.0     0.0     1.000000     6.000000     1.000000
# 50%     500.500000     1.0     0.0     1.000000    12.000000     3.000000
# 75%     750.250000     1.0     0.0     2.000000    18.000000     5.000000
# max    1000.000000     1.0     0.0     2.000000    23.000000     6.000000
#
#         weathersit         temp          hum    windspeed       casual  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.480000     0.205900     0.582480     0.194931     4.921000
# std       0.651171     0.078977     0.187977     0.129126     7.643899
# ...

# %%
# finding num values 

final_data_1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# grapical representation of cloomn for checkinng skewness
sns.histplot(x='temp',data=final_data_1)
# Out:
# <Axes: xlabel='temp', ylabel='Count'>

# %%
# positive skewness (on data tamp)
final_data_1['temp'].skew()
# Out:
# 0.5479968824203467

# %%
final_data_1['temp'].mean(),final_data_1['temp'].mode(),final_data_1['temp'].median()
# Out:
# (0.20590000000000003,
#  0    0.22
#  Name: temp, dtype: float64,
#  0.2)

# %%
# find catagorical and numeric data 
df_cat= final_data_1.select_dtypes(np.object)
df_num= final_data_1.select_dtypes(np.number)
df_cat, df_num
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_688\855293837.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_cat= final_data_1.select_dtypes(np.object)
# (         dteday
#  0    01-01-2011
#  1    01-01-2011
#  2    01-01-2011
#  3    01-01-2011
#  4    01-01-2011
#  ..          ...
#  385  28-01-2011
#  386  28-01-2011
#  387  28-01-2011
#  388  28-01-2011
#  389  29-01-2011
#
#  [1000 rows x 1 columns],
#       instant  season  yr  mnth  hr  weekday  weathersit  temp   hum  \
#  0          1       1   0     1   0        6           1  0.24  0.81
#  1          2       1   0     1   1        6           1  0.22  0.80
#  2          3       1   0     1   2        6           1  0.22  0.80
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import datetime
now= datetime.datetime.now()
date_string= now.strftime('%y%m%d%H%M%S')
date_int= int(date_string)
date_int
# Out:
# 240710160103

# %%
 # encode date colomn
le=LabelEncoder()
final_data_1['en_dteday']=le.fit_transform(final_data_1['dteday'])
final_data_1['en_dteday']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 385    41
# 386    41
# 387    41
# 388    41
# 389    42
# Name: en_dteday, Length: 1000, dtype: int32

# %%
final_data_1['dteday']=final_data_1['en_dteday'].values
final_data_1
# Out:
#      instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       0       1   0     1   0    False        6           1
# 1          2       0       1   0     1   1    False        6           1
# 2          3       0       1   0     1   2    False        6           1
# 3          4       0       1   0     1   3    False        6           1
# 4          5       0       1   0     1   4    False        6           1
# ..       ...     ...     ...  ..   ...  ..      ...      ...         ...
# 385      615      41       1   0     1  20    False        5           2
# 386      616      41       1   0     1  21    False        5           2
# 387      617      41       1   0     1  22    False        5           1
# 388      618      41       1   0     1  23    False        5           1
# 389      619      42       1   0     1   0    False        6           1
#
#      temp   hum  windspeed  casual  registered  cnt  en_dteday
# ...

# %%
 # correlerationn between colomn winnd sepped annd temp
final_data_1['windspeed'].corr(final_data_1['temp'])
# Out:
# 0.1226253256299844

# %%
# ouutlier
sns.boxplot(y=final_data_1['temp'])
# Out:
# <Axes: ylabel='temp'>

# %%
q1=final_data_1['temp'].quantile(0.25)
q1
# Out:
# 0.16

# %%
q3=final_data_1['temp'].quantile(0.75)
q3
# Out:
# 0.24

# %%
IQR=q3-q1

# %%
min_range= q1-(1.5*IQR)
max_range= q3+(1.5*IQR)
min_range, max_range
# Out:
# (0.04000000000000002, 0.36)

# %%
final_data_2=final_data_1[final_data_1['temp']<max_range]

# %%
final_data_2=final_data_1[final_data_1['temp']>min_range]
final_data_2
# Out:
#      instant  dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1       0       1   0     1   0    False        6           1
# 1          2       0       1   0     1   1    False        6           1
# 2          3       0       1   0     1   2    False        6           1
# 3          4       0       1   0     1   3    False        6           1
# 4          5       0       1   0     1   4    False        6           1
# ..       ...     ...     ...  ..   ...  ..      ...      ...         ...
# 385      615      41       1   0     1  20    False        5           2
# 386      616      41       1   0     1  21    False        5           2
# 387      617      41       1   0     1  22    False        5           1
# 388      618      41       1   0     1  23    False        5           1
# 389      619      42       1   0     1   0    False        6           1
#
#      temp   hum  windspeed  casual  registered  cnt  en_dteday
# ...

# %%
final_data_2.shape
# Out:
# (976, 16)

# %%
# write csv file for final data
final_data_2.to_csv('C:\\Users\\pc\\Desktop\\project2\\finaldata.csv')
